# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[2,3,4],[2,4,5]])
B = np.array([[5,6,7],[3,6,5]])

# %%
A
B
# Out:
# array([[5, 6, 7],
#        [3, 6, 5]])

# %%
plt.plot(A)
plt.show()

# %%
plt.plot(B)
plt.show()

# %%
C=np.array(A+B)
C
# Out:
# array([[ 7,  9, 11],
#        [ 5, 10, 10]])

# %%
plt.plot(C)
plt.show()

# %%
C=A-B
C
# Out:
# array([[-3, -3, -3],
#        [-1, -2,  0]])

# %%
plt.plot(C)
plt.show()

# %%
C=A*B
C
# Out:
# array([[10, 18, 28],
#        [ 6, 24, 25]])

# %%
plt.plot(C)
plt.show()

# %%
C=np.dot(A,B)
C
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-1f8cb417fe09> in <module>
# ----> 1 C=np.dot(A,B)
#       2 C
#
# ValueError: shapes (2,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)
